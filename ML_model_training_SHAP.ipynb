# %% [markdown]
# # "A breath of fresh air" - ML model training notebook

# %%
# import libraries and tools
import pandas as pd
import numpy as np
import missingno as msno
import metpy.calc
from metpy.units import units

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px


from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, r2_score, classification_report, confusion_matrix, fbeta_score, make_scorer
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

from variable_names import vars_drop

import preprocessing_pipeline as prepro
import feature_engineering as feng

import warnings
warnings.filterwarnings('ignore')

# eye candy plots
plt.style.use('https://github.com/dhaitz/matplotlib-stylesheets/raw/master/pitayasmoothie-light.mplstyle')
# source https://github.com/dhaitz/matplotlib-stylesheets

# %% [markdown]
# #### Get data and cleaning

# %%
# get data
df = pd.read_csv('data/Train.csv')
## Throw out unwanted variables
df.drop(vars_drop, axis=1, inplace=True)
# Convert wind cartesional components to magnitude and direction 
df = feng.create_wind(df)
# Convert time to datetime and create day-of-week column
df = feng.time_features(df)
# Convert target from float into category labels
df = feng.create_target_labels(df)
## Throw out variables with less than 15 features
df.dropna(thresh=15, inplace=True)

# Create prior features
df = feng.prior_features(df)

# %% [markdown]
# #### Define preprocessor and split data

# %%
non_qnt_cols = ['Place_ID','Date','Place_ID X Date','target','target_cat']
qnt_cols = [col for col in df.columns.to_list() if col not in non_qnt_cols]
cat_cols = ['Place_ID','weekday']

### Define the preprocessor

preprocessor = prepro.make_pipeline(qnt_cols,cat_cols)

## To make time spit, first drop numerical target and unnecessary categories
## Keep target_cat as part of the dataframe

df.drop(['Place_ID X Date','target'], axis=1, inplace=True)
#Perform test train split for time series data
X_train, X_test, y_train, y_test = prepro.test_train_time_split(df,
                                                         target_name='target_cat',
                                                         date_name='Date',
                                                         test_size=0.3)

print(f'X_train shape is{X_train.shape}, y_train shape is {y_train.shape}')
print(f'X_test shape is{X_test.shape}, y_test shape is {y_test.shape}')
# Out:
# X_train shape is(21269, 29), y_train shape is (21269,)
# X_test shape is(9115, 29), y_test shape is (9115,)

# %% [markdown]
# ## Rebalance classes in new dataset

# %%
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

val_cts = y_train.value_counts() # the current counts of each class
vc_min = val_cts.min() # the minimun class

# reduce the larger classes so that they are halfway to min
vc_rus = (val_cts - vc_min)//2 + vc_min 
rus = RandomUnderSampler(sampling_strategy={0: vc_rus[0], 1: vc_rus[1], 2: vc_rus[2]})

# oversample the smaller classes so that they equal the max class
ros = RandomOverSampler()

X_res, y_res = rus.fit_resample(X_train,y_train)
X_res, y_res = ros.fit_resample(X_res,y_res)

# %%
y_res.value_counts()
# Out:
# 0    7966
# 1    7966
# 2    7966
# Name: target_cat, dtype: int64

# %%
def print_results(y_true,y_pred):
    print(f"Average class-weighted f-beta score is {fbeta_score(y_true,y_pred,beta=2,average='weighted'):.2f}")
    print('-------'*10)
    labels = [0,1,2]
    conf = confusion_matrix(y_true,y_pred,labels=labels)
    

    sns.heatmap(conf,annot=True,fmt='g', xticklabels=labels, yticklabels=labels);
    print(classification_report(y_true, y_pred,labels=labels))


## Make a scorer for the gridsearch
fbeta2_scorer = make_scorer(fbeta_score, beta=2, average='weighted')

# %% [markdown]
# ## Baseline

# %%
### Real basline model
y_pred = [2 for _ in y_test]

## print the results
print_results(y_test,y_pred);
# Out:
# Average class-weighted f-beta score is 0.41
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      2274
#            1       0.00      0.00      0.00      2365
#            2       0.49      1.00      0.66      4476
#
#     accuracy                           0.49      9115
#    macro avg       0.16      0.33      0.22      9115
# weighted avg       0.24      0.49      0.32      9115

# %% [markdown]
# #### Logistic Regression model

# %%
param_grid = {'log_reg__max_iter': [1000,]} 
## NOTE! Your paramgrid for model parameters must have the name of your model
## in the pipeline separated by two underscores. See here:
## log_reg + __ + parameter name

### Create a pipeline with the chosen baseline model and preprocessor
base_log = Pipeline([
    ('preprocessor', preprocessor),
    ('log_reg', LogisticRegression())
])


#Create a gridsearch for cross validation
gs_baseline = GridSearchCV(base_log, param_grid=param_grid, cv=10, scoring=fbeta2_scorer, 
                           verbose=0, n_jobs=-1)


## Fit the model using gridsearch and get best model
gs_baseline.fit(X_res, y_res);
best_model = gs_baseline.best_estimator_

## Make predictions on test set
y_pred = best_model.predict(X_test);

## print the results
print_results(y_test,y_pred);
# Out:
# Average class-weighted f-beta score is 0.68
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.72      0.67      2274
#            1       0.47      0.46      0.46      2365
#            2       0.84      0.79      0.81      4476
#
#     accuracy                           0.68      9115
#    macro avg       0.65      0.65      0.65      9115
# weighted avg       0.69      0.68      0.69      9115

# %% [markdown]
# #### Random forest model

# %%
param_grid = {'rmf__n_estimators': range(10,200,5),
              'rmf__max_depth': [None,] + list(range(10,100,5)),
              'rmf__min_samples_leaf': range(1,10),
              'rmf__max_features': ("sqrt","log2",2,5,10)}

### Create a pipeline with the chosen baseline model and preprocessor
rmfor = Pipeline([
    ('preprocessor', preprocessor),
    ('rmf', RandomForestClassifier())
])


#Create a gridsearch for cross validation
rs_rmfor = RandomizedSearchCV(rmfor, param_distributions=param_grid, cv=5, scoring=fbeta2_scorer, 
                           verbose=0, n_jobs=-1, n_iter=20)


## Fit the model using gridsearch and get best model
rs_rmfor.fit(X_res, y_res);
best_model = rs_rmfor.best_estimator_

## Make predictions on test set
y_pred = best_model.predict(X_test);

## print the results
print_results(y_test,y_pred);
# Out:
# Average class-weighted f-beta score is 0.66
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.67      0.64      2274
#            1       0.47      0.36      0.41      2365
#            2       0.77      0.83      0.80      4476
#
#     accuracy                           0.67      9115
#    macro avg       0.62      0.62      0.61      9115
# weighted avg       0.65      0.67      0.66      9115

# %%
### random forest params
best_model['rmf']
# Out:
# RandomForestClassifier(max_depth=90, max_features=2, n_estimators=60)

# %% [markdown]
# #### Support Vector Machine Model

# %%
from sklearn.svm import SVC
param_grid = {'svc__class_weight': [{0:2,1:2,2:1}],
              'svc__kernel' : ['linear'],
            
              
              } #{'n_neighbors': [10,]} #list(range(5,50,5)

### Create a pipeline with the chosen baseline model and preprocessor
base_log = Pipeline([
    ('preprocessor', preprocessor),
    ('svc', SVC())
])


#Create a gridsearch for cross validation
gs_baseline = GridSearchCV(base_log, param_grid=param_grid, cv=10, scoring=fbeta2_scorer, 
                           verbose=0, n_jobs=-1)


## Fit the model using gridsearch and get best model
gs_baseline.fit(X_train, y_train);
best_model = gs_baseline.best_estimator_

## Make predictions on test set
y_pred = best_model.predict(X_test);

## print the results
print('Best parameters:', gs_baseline.best_params_)
print_results(y_test,y_pred);
# Out:
# Best parameters: {'svc__class_weight': {0: 2, 1: 2, 2: 1}, 'svc__kernel': 'linear'}
# Average class-weighted f-beta score is 0.69
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.72      0.68      2274
#            1       0.46      0.47      0.47      2365
#            2       0.84      0.79      0.81      4476
#
#     accuracy                           0.69      9115
#    macro avg       0.65      0.66      0.65      9115
# weighted avg       0.69      0.69      0.69      9115

# %%
d = {'Model':['Baseline','Logistic Reg w/o Loc','Logistic Reg','SVM','Random Forest'], 'F1 beta' :[0.41, 0.5, 0.69,0.69,0.6], 'Rcl Good' :[0,0.39, 0.73,0.72,0.68], 'Rcl Fair':[0, 0.05,0.47,0.47,0.30], 'Rcl Poor':[1, 0.85,0.78,0.79,0.72]}

df_bar = pd.DataFrame(d)
df_bar
# Out:
#                   Model  F1 beta  Rcl Good  Rcl Fair  Rcl Poor
# 0              Baseline     0.41      0.00      0.00      1.00
# 1  Logistic Reg w/o Loc     0.50      0.39      0.05      0.85
# 2          Logistic Reg     0.69      0.73      0.47      0.78
# 3                   SVM     0.69      0.72      0.47      0.79
# 4         Random Forest     0.60      0.68      0.30      0.72

# %%
ax = df_bar.plot(x="Model", y=["F1 beta", "Rcl Good", "Rcl Fair", "Rcl Poor"], kind="bar", rot=0, figsize=(8,8), color=('#A4B0D1','#88DC9F','#E5A358','#EC4542'))
ax.legend(bbox_to_anchor=(1,0.5), prop={'size':9})
ax.set_facecolor("white")
plt.ylabel('Score', fontsize=12)
plt.suptitle('Model Score Comparison', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Model Score Comparison')

# %% [markdown]
# ### Simplify features and train a new model

# %%
# get data
df_simp = pd.read_csv('data/Train.csv')
## Throw out unwanted variables
df_simp.drop(vars_drop, axis=1, inplace=True)
# Convert wind cartesional components to magnitude and direction 
df_simp = feng.create_wind(df_simp)
# Convert time to datetime and create day-of-week column
df_simp = feng.time_features(df_simp)
# Convert target from float into category labels
df_simp = feng.create_target_labels(df_simp)
## Throw out variables with less than 15 features
df_simp.dropna(thresh=15, inplace=True)

# %%
import re
from sklearn.preprocessing import StandardScaler
list_cols = df_simp.columns.to_list()
#print(list_cols)
## Column density - merge into one variable
r = re.compile(".*column_number*")

newlist = list(filter(r.match, list_cols)) # Read Note below
#print(newlist)
new_values = df_simp[newlist]
sscal = StandardScaler()
new_values = sscal.fit_transform(new_values)
new_values_mean_scaled = new_values.mean(axis=1)
df_simp['column_density'] = new_values_mean_scaled
df_simp.drop(newlist, axis=1, inplace=True)

## Absorbing index - merge into one variable
r = re.compile(".*absorbing*")

newlist = list(filter(r.match, list_cols)) # Read Note below
#print(newlist)
new_values = df_simp[newlist]
sscal = StandardScaler()
new_values = sscal.fit_transform(new_values)
new_values_mean_scaled = new_values.mean(axis=1)
df_simp['absorbing_aerosol'] = new_values_mean_scaled
df_simp.drop(newlist, axis=1, inplace=True)


## Weekday to binary, it is a weekday or weekend?
df_simp.weekday = (df_simp.weekday < 5).astype(int)

## Drop other features
list_drop_new = ['specific_humidity_2m_above_ground',
                 ]

df_simp.drop(list_drop_new, axis=1, inplace=True)

## Prior variables
df_simp = feng.prior_features(df_simp,['Place_ID','precipitable_water_entire_atmosphere',
        'relative_humidity_2m_above_ground',
        'temperature_2m_above_ground', 
        'winddir', 'windspeed'])

# %%
non_qnt_cols = ['Place_ID','Date','Place_ID X Date','target','target_cat'] #'Place_ID',
qnt_cols = [col for col in df_simp.columns.to_list() if col not in non_qnt_cols]
cat_cols = ['Place_ID'] #['weekday']

### Define the preprocessor

preprocessor = prepro.make_pipeline(qnt_cols,cat_cols)

## To make time spit, first drop numerical target and unnecessary categories
## Keep target_cat as part of the dataframe

df_simp.drop(['Place_ID X Date','target'], axis=1, inplace=True)
#Perform test train split for time series data
X_train, X_test, y_train, y_test = prepro.test_train_time_split(df_simp,
                                                         target_name='target_cat',
                                                         date_name='Date',
                                                         test_size=0.3)

print(f'X_train shape is{X_train.shape}, y_train shape is {y_train.shape}')
print(f'X_test shape is{X_test.shape}, y_test shape is {y_test.shape}')
# Out:
# X_train shape is(21269, 18), y_train shape is (21269,)
# X_test shape is(9115, 18), y_test shape is (9115,)

# %% [markdown]
# ### SHAP Calculations

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer


def make_pipeline_2(qnt_cols,cat_cols):
    qnt_pipeline = Pipeline([
        ('scale_qnt', StandardScaler()),
        ('impute_qnt', SimpleImputer(strategy='median')),
    ]) # columns with quantitative data

    cat_pipeline = Pipeline([
        ('impute_cat', SimpleImputer(strategy='constant', fill_value='missing')),
        ('ohe_cat', OneHotEncoder(handle_unknown='ignore', sparse=False))
    ]) # columns with categorical data

    if cat_cols==None:
            preprocessor = ColumnTransformer([
            ('qnt', qnt_pipeline, qnt_cols)
        ]) # only quant to transform
    else:
        preprocessor = ColumnTransformer([
            ('qnt', qnt_pipeline, qnt_cols),
            ('cat', cat_pipeline, cat_cols)
        ]) # combining quant and cat to column transformer
    return preprocessor

pipeline2 = make_pipeline_2(qnt_cols,cat_cols)
model = LogisticRegression(max_iter=2000,class_weight='balanced')

X_train_transform = pipeline2.fit_transform(X_train)
X_test_transform = pipeline2.transform(X_test)

model.fit(X_train_transform,y_train)


## Make predictions on test set
y_pred = model.predict(X_test_transform);

## print the results
#print('Best parameters:', model.get_params())
print_results(y_test,y_pred);
# Out:
# Average class-weighted f-beta score is 0.69
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.70      0.68      2274
#            1       0.48      0.47      0.47      2365
#            2       0.83      0.81      0.82      4476
#
#     accuracy                           0.69      9115
#    macro avg       0.65      0.66      0.65      9115
# weighted avg       0.69      0.69      0.69      9115

# %%
final_feature_names = np.concatenate( ( np.array(qnt_cols),
            pipeline2.transformers_[1][1]['ohe_cat'].get_feature_names()
))

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# explainer = shap.Explainer(model,feature_names=final_feature_names)


explainer = shap.LinearExplainer(model, X_train_transform, 
                                 feature_perturbation="interventional",feature_names=final_feature_names)

shap_values = explainer(X_test_transform)

# %%
print(shap_values.shape)
print(final_feature_names.shape)
print(X_test_transform.shape)
# Out:
# (9115, 356, 3)
# (356,)
# (9115, 356)

# %%
val_shap = shap_values.values
print(shap_values.values.shape)
#weekdays_shapval = val_shap[:,-7:,:].sum(axis=1, keepdims=True)
location_shapval = val_shap[:,-339:,:].sum(axis=1, keepdims=True) #.sum(axis=1)
qnt_shapval = val_shap[:,:-339,:]

new_shapval = np.concatenate((location_shapval,qnt_shapval),axis=1)

labels = ['location'] + qnt_cols

print(new_shapval.shape)

shap_values.values = new_shapval
# Out:
# (9115, 356, 3)
# (9115, 18, 3)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 14
#      11 print(new_shapval.shape)
#      13 shap_values.values = new_shapval
# ---> 14 shap_values.feature_names = final_feature_names
#
# File ~/neuefische/ml-project-air-pollution/.venv/lib/python3.9/site-packages/shap/_explanation.py:240, in Explanation.feature_names(self, new_feature_names)
#     238 @feature_names.setter
#     239 def feature_names(self, new_feature_names):
# --> 240     self._s.feature_names = new_feature_names
#
# File ~/neuefische/ml-project-air-pollution/.venv/lib/python3.9/site-packages/slicer/slicer.py:183, in Slicer.__setattr__(self, key, value)
#     181         if old_alias:
#     182             self._alias_lookup.delete(old_alias)
# --> 183         self._alias_lookup.update(value)
#     184 else:
#     185     if key == "o":
#
# File ~/neuefische/ml-project-air-pollution/.venv/lib/python3.9/site-packages/slicer/slicer_internal.py:273, in AliasLookup.update(self, alias)
#     271 dim_lookup = self._lookup[dim]
#     272 # NOTE: Alias must be backed by either a list or dictionary.
# --> 273 itr = enumerate(alias.o) if isinstance(alias.o, list) else alias.o.items()
#     274 for i, x in itr:
#     275     if x not in dim_lookup:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'items'

# %%
dat_shap = shap_values.data
print(shap_values.data.shape)

location_data = dat_shap[:,-339:].sum(axis=1, keepdims=True) #.sum(axis=1)
qnt_data = dat_shap[:,:-339]

new_data = np.concatenate((location_data,qnt_data),axis=1)

labels = ['location'] + qnt_cols

print(new_data.shape)
shap_values.data = new_data
# Out:
# (9115, 356)
# (9115, 18)

# %%
all_features = labels
test_shap = X_test_transform

# %%
len(labels)
# Out:
# 18

# %%
which_feat_names = list(np.array(labels)[which_feat])

# %%
which_feat = [0,3,9,11,15,17]

# %%
shap.summary_plot(shap_values[:,which_feat,0], shap_values.data[:,which_feat], feature_names=which_feat_names )

# %%
shap.summary_plot(shap_values[:,which_feat,1], shap_values.data[:,which_feat], feature_names=which_feat_names )

# %%
shap.summary_plot(shap_values[:,which_feat,2], shap_values.data[:,which_feat], feature_names=which_feat_names )

# %%
shap.summary_plot([shap_values[:,which_feat,i] for i in range(3) ], 
                  shap_values.data[:,which_feat], 
                  feature_names=which_feat_names, class_names= ['Good','Fair','Poor'] )

# %%
shap_values2 = explainer(X_test_transform)

print(shap_values2.feature_names[:-338])
print(shap_values2.feature_names[-339])
# Out:
# ['precipitable_water_entire_atmosphere', 'relative_humidity_2m_above_ground', 'temperature_2m_above_ground', 'L3_CLOUD_cloud_fraction', 'L3_CLOUD_cloud_optical_depth', 'L3_CLOUD_cloud_top_pressure', 'L3_CLOUD_surface_albedo', 'winddir', 'windspeed', 'weekday', 'column_density', 'absorbing_aerosol', 'precipitable_water_entire_atmosphere_prior', 'relative_humidity_2m_above_ground_prior', 'temperature_2m_above_ground_prior', 'winddir_prior', 'windspeed_prior', 'x0_010Q650']
# x0_010Q650

# %%
shap_values2[:,-339].values = shap_values2[:,-339:].sum(1)
shap_values2.values = shap_values2[:,:-340]
shap_values2.feature_names = shap_values2.feature_names[:-340]
shap_values2.feature_names[-1] = 'location'

# %%
y_pred = model.predict(X_test_transform)
y_0 = (y_pred == 0)
y_1 = (y_pred == 1)

# %%
shap_plt = [shap_values2.values[y_0,:,0],shap_values2.values[y_1,:,1]]
shap.summary_plot(
                  shap_plt, 
                  [shap_values2.data[y_0,:],shap_values2.data[y_1,:]],
                  class_names= ['Good','Fair'], 
                  feature_names= shap_values2.feature_names,
                  plot_type="bar",)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[254], line 2
#       1 shap_plt = [shap_values2.values[y_0,:,0],shap_values2.values[y_1,:,1]]
# ----> 2 shap.summary_plot(
#       3                   shap_plt,
#       4                   [shap_values2.data[y_0,:],shap_values2.data[y_1,:]],
#       5                   class_names= ['Good','Fair'],
#       6                   feature_names= shap_values2.feature_names,
#       7                   plot_type="bar",)
#
# File ~/neuefische/ml-project-air-pollution/.venv/lib/python3.9/site-packages/shap/plots/_beeswarm.py:596, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, auto_size_plot, use_log_scale)
#     593 if sort:
#     594     # order features by the sum of their effect magnitudes
#     595     if multi_class:
# --> 596         feature_order = np.argsort(np.sum(np.mean(np.abs(shap_values), axis=1), axis=0))
#     597     else:
#     598         feature_order = np.argsort(np.sum(np.abs(shap_values), axis=0))
#
# TypeError: bad operand type for abs(): 'Explanation'
